# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('results.csv')
analytical = np.loadtxt('/mnt/external_data/maruthi/my_codes/compressible_euler_1d/output/shock_tube.dat')

# %%
plt.plot(analytical[:,0], analytical[:,1])
plt.plot(data['x'], data['rho'])

# %%
plt.plot(analytical[:,0], analytical[:,2])
plt.plot(data['x'], data['u'])

# %%
plt.plot(analytical[:,0], analytical[:,3])
plt.plot(data['x'], data['p'])
